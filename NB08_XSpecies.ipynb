# %%
import os
import pandas
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits as mplot3d
import seaborn as sns
from copy import deepcopy
from scipy import stats
from matplotlib.colors import Normalize
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.multitest import multipletests
from sklearn.preprocessing import MinMaxScaler, StandardScaler
# Out:
# /Users/jacobv/pls_gxp/lib/python3.7/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# # Prep data

# %% [markdown]
# ### Instructions
# To run this notebook, you will have to download the "Adult human, chimpanzee, macaque data" from http://evolution.psychencode.org/#
#
# Keep track of where you save the data to. Might be simples to save it into the data/ directory of this repo

# %%
os.chdir('data/')
os.system('wget https://www.dropbox.com/sh/zx0va2j8tbbyhux/AAD1sXx9KvxuKZfz_fS6U8j8a/PEC_nhp_melt.csv?dl=1')
os.chdir('../')

# %%
df = pandas.read_csv('./data/PEC_nhp_melt.csv')
figdir = './figures/'

# %% [markdown]
# #### Harmonize data
# First we want to harmonize the dataset with Allen and pull out the PLS Components for each of the samples here

# %%
df.loc[:,'gene_symbol'] = [x.split('|')[-1] for x in df.ProbeID.values]

# %%
# This dataframe was created in the N3_PLS_ModelExploration notebook
allcomps = pandas.read_csv('./tables/all_comps.csv',index_col=0)
allcomps.index = allcomps.gene_symbol.values
allcomps.head()
# Out:
#          gene_symbol                     gene_name        C1        C2  \
# A1BG            A1BG        alpha-1-B glycoprotein  0.002967  0.001055
# A1BG-AS1    A1BG-AS1                           NaN  0.001287 -0.001796
# A2M              A2M         alpha-2-macroglobulin  0.003203  0.003630
# A2ML1          A2ML1  alpha-2-macroglobulin-like 1 -0.000960 -0.003713
# A3GALT2      A3GALT2                           NaN -0.002451  0.001712
#
#                 C3  C1_genelist  C2_genelist  C3_genelist
# A1BG     -0.005412          0.0          0.0          0.0
# A1BG-AS1  0.006987          0.0          0.0          0.0
# A2M       0.000001          0.0          0.0          0.0
# A2ML1    -0.009880          0.0          0.0          0.0
# A3GALT2   0.003116          0.0          0.0          0.0

# %%
# find common genes across datasets
shared = set(df.gene_symbol.values) & set(allcomps.index)

# %%
# crop to shared genes
df = df[df.gene_symbol.isin(shared)]

# %% [markdown]
# Here, we're calculating the PLS Component expression for each component for each human and primate tissue sample available.

# %% [markdown]
# #### Recalculate PLS based on shared genes

# %%
# Generated in NB1
hbigdf = pandas.read_csv('data/expression.csv') 
allendir = '/Users/jacobv/abagen-data/microarray/'
probes = pandas.read_csv(os.path.join(allendir,'normalized_microarray_donor10021/Probes.csv'))
# Generated in NB2
hgdf = pandas.read_csv('data/PLS_GXp_gdf.csv',index_col=0) # Generated in NB2
hbigdf.index = hgdf.index
hbigdf.drop('well_id',axis=1,inplace=True)

# %%
pivoted = df.groupby(['ID','ROI','gene_symbol'])['value'].aggregate('mean').unstack()

# %%
hbigdf = hbigdf[pivoted.columns]

# %%
from sklearn.decomposition import PCA
from sklearn.cross_decomposition import PLSRegression

# recover the PCA results
pcamod = PCA(n_components=100, random_state=123).fit(hbigdf)
pca_tfm = pandas.DataFrame(pcamod.transform(hbigdf),index = hgdf.index)

# %%
# refit PLS with only GTEx genes
full_y = hgdf[['mni_nlin_y','mni_nlin_z','abs_mni_nlin_x']]
pls_mod = PLSRegression(n_components=3)
pls_mod.fit(pca_tfm, full_y)
# Out:
# PLSRegression(n_components=3)

# %%
# As with GTEx, we'll need to invert LV3

mp = np.ones(pls_mod.x_rotations_.shape)
mp[:,2] = -1
pls_mod.x_rotations_ *= mp

# %% [markdown]
# **Warning!** This code takes quite a long time to run.

# %%
# There is surely a faster way of doing this but I was lazy.
# Took awhile to run on my computer

gdf = pandas.DataFrame()
count = 0
# for each subject
for i,ID in enumerate(df.ID.unique()):
    print('working on %s of 16'%(i+1))
    # for each region
    for region in df.ROI.unique():
        # pull out relevant data
        jnk = pandas.DataFrame(df[(df.ROI==region) & (df.ID==ID)],copy=True)
        if jnk.shape[0] == 0: continue # skip if region missing
        # add info to new spreadsheet
        gdf.loc[count,'ID'] = jnk.iloc[0]['ID']
        gdf.loc[count,'ROI'] = jnk.iloc[0]['ROI']
        gdf.loc[count,'Species'] = jnk.iloc[0]['Species']
        # prep for dot product (aka the "prediction")
        # first drop duplicates
        dups = []
        catch = []
        for ind,row in jnk.iterrows():
            x = row['gene_symbol']
            if x in catch:
                dups.append(ind)
            else:
                catch.append(x)
        jnk.drop(dups,axis=0,inplace=True)
        jnk.index = jnk.gene_symbol.values
        jnk = jnk.loc[pivoted.columns]
        # find PLS expression for each component
        npcatfm = pcamod.transform(jnk['value'].values.reshape(1,-1))
        tfmx = pls_mod.transform(npcatfm)
        for c in range(1,4):
            gdf.loc[count,'C%s_exp'%c] = tfmx[0,c-1]
        count+=1
# Out:
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16

# %%
# Might want to save that so you don't have to do it again

#gdf.to_csv('./data/PEC_nhp_indiv_withCs.csv')

# %%
# And load it to start from here
gdf = pandas.read_csv('data/PEC_nhp_indiv_withCs.csv',
                     index_col=0)

# %%
# map each region to one of the AHBA regions
mapper = {'Sensorimotor': ['S1C','M1C'],
          'Limbic': ['HIP','AMY'],
          'Cerebellum': ['CBC'],
          'Forebrain': ['NAC'],
          'Striatum': ['STR'],
          'Frontal': ['OFC','VFC','DFC','MFC'],
          'Temporal': ['STC','A1C','ITC'],
          'Parietal': ['IPC',],
          'Occipital': ['V1C'],
          'Thalamus': ['MD']
         }
for name, div in mapper.items():
    gdf.loc[gdf[gdf.ROI.isin(div)].index,'MacroStructure'] = name

# %%
# remove outliers
#gdf.drop([1099,777],inplace=True)

# %% [markdown]
# # Visualization (for fun)
# For fun, we can visualize the dispersion of smaples across components

# %%
sns.set_context('notebook',font_scale=1.5)

# for each species separately
for species in gdf.Species.unique():
    if not pandas.notnull(species): continue
    print(species)
    adf = gdf[gdf.Species==species]
    # get means and sds across donors
    means = adf.groupby('MacroStructure')[['C1_exp','C2_exp','C3_exp']].mean()
    stds = adf.groupby('MacroStructure')[['C1_exp','C2_exp','C3_exp']].std()
    stds.columns = ['C1_sd','C2_sd','C3_sd']
    # set up plotting dataframe for easy reference
    plotr = pandas.concat([means,stds],axis=1)
    plotr.loc[:,'region'] = plotr.index
    # start building plot
    ax = plt.axes(projection='3d')
    # plot confidence intervals across all three dimensions
    for i,row in plotr.iterrows():
        c1_mn = row['C1_exp']
        c2_mn = row['C2_exp']
        c3_mn = row['C3_exp']
        c1_sd = row['C1_sd']
        c2_sd = row['C2_sd']
        c3_sd = row['C3_sd']
        ax.plot3D([c1_mn-c1_sd,c1_mn+c1_sd], [c2_mn,c2_mn], [c3_mn,c3_mn], 'gray')
        ax.plot3D([c1_mn,c1_mn], [c2_mn-c2_sd,c2_mn+c2_sd], [c3_mn,c3_mn], 'gray')
        ax.plot3D([c1_mn,c1_mn], [c2_mn,c2_mn], [c3_mn-c3_sd,c3_mn+c3_sd], 'gray')
    # plot markers
    ax.scatter3D(plotr.C1_exp, plotr.C2_exp, plotr.C3_exp, c=range(len(plotr)),cmap='tab10',
                s=100)
    # decorate
    plt.xlabel('C1')
    plt.ylabel('C2')
    ax.set_zlabel('C3')
    ax.set_xticklabels(['' for x in ax.get_xticklabels()])
    ax.set_yticklabels(['' for x in ax.get_yticklabels()])
    ax.set_zticklabels(['' for x in ax.get_zticklabels()])
    ax.set_title(species)
    plt.show()
# Out:
# Human
# /Users/jacobv/pls_gxp/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/jacobv/pls_gxp/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/jacobv/pls_gxp/lib/python3.7/site-packages/ipykernel_launcher.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator
# Chimpanzee
# Macaque

# %% [markdown]
# # Calculate reproduction of PLS Components
# Here we are using the same logic we did in the `GTExWorkup.ipynb` and `BrainSpanValidation.ipynb` notebooks. We are seeing how well the PLS Components trained in AHBA replicate in *individuals* across these three datasets. Importantly, two of the datasets are non-human primates, which include data from macaques and chimps, respectively

# %% [markdown]
# The code below is copied (and adapted) from code used in `GTExWorkup.ipynb` and `BrainSpanValidation.ipynb`, so see these notebooks for more thorough documentation

# %% [markdown]
# #### First across entire human dataset (to compare to other replications)

# %%
abac2 = pandas.read_csv('data/GCorr_BSComp_ABA_C2_data.csv',
                       index_col=0)
abac2.columns = ['ABA_mean','ABA_sem']
print('shared:',set(abac2.index) & set(gdf.MacroStructure.unique()))
print('missing:',set(gdf.MacroStructure.unique()) - set(abac2.index))

bsc2 = pandas.pivot_table(gdf,
                            #gdf[gdf.Age_Stage=='adult'],
                          values='C2_exp',
                             index='MacroStructure',aggfunc=np.mean
                            )
for div in bsc2.index:
    sem = gdf[gdf.MacroStructure==div]['C2_exp'].sem()
    bsc2.loc[div,'sem'] = sem
bsc2.columns = ['BS_mean','BS_sem']

c2_comp = pandas.concat([bsc2,abac2],axis=1,sort='True').dropna()
c2_comp.loc[:,'region'] = c2_comp.index
c2_comp.head()
# Out:
# shared: {'Thalamus', 'Striatum', 'Temporal', 'Occipital', 'Frontal', 'Sensorimotor', 'Parietal', 'Limbic', 'Cerebellum'}
# missing: set()
#              BS_mean    BS_sem  ABA_mean   ABA_sem      region
# Cerebellum -4.191678  0.196392 -0.706893  0.019982  Cerebellum
# Frontal    -2.977417  0.218577  0.789432  0.031165     Frontal
# Limbic     -2.880843  0.165415  0.030956  0.039398      Limbic
# Occipital  -6.481108  0.319687 -1.655174  0.042085   Occipital
# Parietal   -5.721942  0.225550 -1.124981  0.031968    Parietal

# %%
# z-score data to account for standardized vs. non-standardize nature of the two datasets
n_comps = 3
for i in range(1,(n_comps+1)):
    vals = StandardScaler().fit_transform(gdf.loc[:,'C%s_exp'%i
                                                 ].values.reshape(-1,1)
                                         )[:,0]
    gdf.loc[:,'zC%s_exp'%i,] = vals

# %%
# note this analysis is only performed on the adult brainspan samples
sns.set_context('notebook',font_scale=2)
pals = ['cividis','viridis','magma']
for i in range(1,(n_comps+1)):
    # read allen data
    aba = pandas.read_csv('data/GCorr_BSComp_ABA_C%s_data.csv'%i,
                       index_col=0)
    aba.columns = ['ABA_mean','ABA_sem']
    # prep brainspan data
    bs = pandas.pivot_table(
                            gdf[gdf.Species=='Human'],# just the humans!
                          values='C%s_exp'%i,
                             index='MacroStructure',aggfunc=np.mean
                            )
    # calculate SEM (I don't think i actually use this)
    for div in bs.index:
        sem = gdf[gdf.MacroStructure==div]['C%s_exp'%i].sem()
        bs.loc[div,'sem'] = sem
    bs.columns = ['PEC_mean','PEC_sem']
    # build comparison dataframe
    comp = pandas.concat([bs,aba],axis=1,sort='True').dropna()
    comp.loc[:,'region'] = c2_comp.index
    
    # colors
    cmap = sns.color_palette(pals[i-1],as_cmap=True)
    sg = comp.ABA_mean.values
    scaled_sg = MinMaxScaler().fit_transform(sg.reshape(-1,1))[:,0]
    norm = Normalize(vmin=np.min(scaled_sg), 
                                       vmax=np.max(scaled_sg))
    cscale = cmap(norm(scaled_sg))
    
    # plot
    g=sns.lmplot(x='ABA_mean',y='PEC_mean',data=comp,
           scatter_kws={'marker':'o','s':200,'color':cscale},
               line_kws={'color':'k'}
          )
    # stats
    r,p = stats.pearsonr(comp.ABA_mean.values,comp.PEC_mean.values)
    print('r = %s, p = %s'%(round(r,3),round(p,3)))
    # decorate
    for it,div in enumerate(comp.sort_values('ABA_mean').index):
        x = comp.loc[div,'ABA_mean']
        y = comp.loc[div,'PEC_mean']
        dist = len(div)*.02
        if it%2==0:
            plt.text(x, y,div,{'size':14})
        else:
            plt.text(x, y,div,{'size':14},
                     )
    plt.xlabel('LV%s: AHBA'%i)
    plt.ylabel('LV%s: PsychENCODE'%i)
    plt.text(0.7,0.1,'r = %s'%round(r,3),transform=g.ax.transAxes)
    #plt.savefig(os.path.join(figdir,'PsyENC_Repl_C%s_ROTATED.pdf'%i), bbox_inches='tight')
    plt.show()
# Out:
# r = 0.961, p = 0.0
# r = 0.912, p = 0.001
# r = 0.876, p = 0.002

# %% [markdown]
# #### Now across individual species

# %%
gpdfs = {}
for i in range(1,4):
    gpdf = gdf[['ID','C%s_exp'%i,'MacroStructure']
                  ].set_index(['ID'],append=True
                             ).pivot_table(index='ID',
                                           columns='MacroStructure',
                                           values='C%s_exp'%i)
    for ind,row in gpdf.iterrows():
        n_valid = len([x for x in row.values if pandas.notnull(x)])
        gpdf.loc[ind,'n_valid'] = n_valid
    gpdfs.update({i: gpdf})

# %%
for c in range(1,4):
    cdf = gpdfs[c]
    aba = pandas.read_csv('data/GCorr_BSComp_ABA_C%s_data.csv'%c,
                       index_col=0)
    aba.columns = ['ABA_mean','ABA_sem']
    aba = aba.loc[cdf.columns[:-1]]
    for i,row in cdf.iterrows():
        forcorr = pandas.DataFrame(aba,copy=True)
        if row['n_valid'] > 4:
            forcorr.loc[:,'gvec'] = row.values[:-1]
            forcorr.dropna(inplace=True)
            r = stats.pearsonr(forcorr['ABA_mean'].values,
                              forcorr['gvec'].values)[0]
            rho = stats.spearmanr(forcorr['ABA_mean'].values,
                              forcorr['gvec'].values)[0]
            cdf.loc[i,'C%s_r'%c] = r
            cdf.loc[i,'C%s_rho'%c] = rho

# %%
cols = ['ID', 'Species',]
subsum = pandas.DataFrame(gpdfs[1].index)
for col in cols:
    subsum.loc[:,col] = gdf.groupby('ID')[col].first().values
for c in range(1,4):
    subsum.loc[:,'C%s_r'%c] = gpdfs[c].loc[:,'C%s_r'%c].values
    subsum.loc[:,'C%s_rho'%c] = gpdfs[c].loc[:,'C%s_rho'%c].values
    subsum.loc[:,'n_valid'] = gpdfs[c].loc[:,'n_valid'].values

# %% [markdown]
# Now that we have the individual level correlations to AHBA components across all individuals and species, let's plot them!

# %%
# Melt the dataset for easier plotting
subsum.loc[:,'ind'] = range(len(subsum))
tall = subsum.melt('ind',['C1_r','C2_r','C3_r'],'component','expr')
tall.loc[:,'Species'] = subsum.Species.tolist() * 3

# %%
# Plot
sns.swarmplot(x='component',y='expr',hue='Species',data=tall,dodge=True)
g = sns.boxplot(x='component',y='expr',hue='Species',data=tall,color='gray')
plt.ylabel('Correlation w/ AHBA Component')
plt.xlabel('')
g.set_xticklabels(['LV1','LV2','LV3'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.ylim(0,1)
plt.setp(g.artists, edgecolor = 'k', facecolor='w')
plt.setp(g.lines, color='k')
#plt.savefig(os.path.join(figdir,'XSpecies_BasicBox.pdf'),bbox_inches='tight')
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# Let's do a quick two-way ANOVA to test if there are significant differences in similarity to the discovery dataset by species, by component, or an interaction

# %%
mod = smf.ols('expr ~ C(Species) + C(component) + C(Species):C(component)', data=tall).fit()
table = sm.stats.anova_lm(mod, typ=2)

# %%
table.round(3)
# Out:
#                          sum_sq    df       F  PR(>F)
# C(Species)                0.017   2.0   3.095   0.057
# C(component)              0.520   2.0  96.716   0.000
# C(Species):C(component)   0.037   4.0   3.434   0.017
# Residual                  0.105  39.0     NaN     NaN

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
print(pairwise_tukeyhsd(tall.expr, groups=tall['Species']))
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================
#   group1    group2 meandiff p-adj   lower  upper  reject
# --------------------------------------------------------
# Chimpanzee   Human    0.044 0.5545 -0.0587 0.1467  False
# Chimpanzee Macaque   0.0152    0.9 -0.0921 0.1225  False
#      Human Macaque  -0.0288 0.7586 -0.1315 0.0739  False
# --------------------------------------------------------

# %%
print(pairwise_tukeyhsd(tall.expr, groups=tall['component']))
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   C1_r   C2_r  -0.0688 0.0056 -0.1196  -0.018   True
#   C1_r   C3_r  -0.2469  0.001 -0.2977 -0.1961   True
#   C2_r   C3_r  -0.1781  0.001 -0.2289 -0.1273   True
# ----------------------------------------------------

# %%
# Print min and max r-value for each component and species
for comp in tall.component.unique():
    for species in tall.Species.unique():
        vals = tall[(tall.Species==species) & (tall.component==comp)].expr.values
        print('%s %s: Min = %s, Max = %s'%(comp,species,np.min(vals),np.max(vals)))
# Out:
# C1_r Human: Min = 0.9024613798422333, Max = 0.9774904639199674
# C1_r Chimpanzee: Min = 0.9165509631515781, Max = 0.9647146804863589
# C1_r Macaque: Min = 0.9119218109254938, Max = 0.9428679215467829
# C2_r Human: Min = 0.8107197734151456, Max = 0.9222283893505655
# C2_r Chimpanzee: Min = 0.7966975306044964, Max = 0.9289930117659564
# C2_r Macaque: Min = 0.854042211368134, Max = 0.933388929390127
# C3_r Human: Min = 0.7066381309310711, Max = 0.8544019330262816
# C3_r Chimpanzee: Min = 0.45819433881785443, Max = 0.7227211753541445
# C3_r Macaque: Min = 0.603420974416517, Max = 0.7727532484062283

# %% [markdown]
# # Null model

# %% [markdown]
# These correlations are all really high, and I think it's natural to wonder if the data guarantees a high correlation. So, in order to test if the within-subject r-values are greater than chance given the data, and to extract exact p-values, we'll do a bit of null modeling.
#
# ***WARNING!!!:*** This cell takes *forever* to run. On my (pretty fast) laptop, it took ~18+ hours. Maybe not worth it to run?

# %%
n_iter = 100 # number of iterations, 100 should be fine for now
results = []

# for each iteration
for it in range(n_iter):
    # do shuffle
    print('working on iteration',(it+1),'of',n_iter)
    print('calculating random expression')
    randies = {}
    # set the random state
    prng = np.random.RandomState(123+it)
    # shuffle the columns (genes)
    rarr = prng.choice(pivoted.columns,len(pivoted.columns),replace=False)
    # prep a null results data frame
    jdf = pandas.DataFrame()
    catch = []
    count = 0
    # run same code as above to go through each subject and region
    for i,ID in enumerate(df.ID.unique()):
        print('working on %s of 16'%(i+1))
        for region in df.ROI.unique():
            jnk = pandas.DataFrame(df[(df.ROI==region) & (df.ID==ID)],copy=True)
            if jnk.shape[0] == 0: continue
            jdf.loc[count,'ID'] = jnk.iloc[0]['ID']
            jdf.loc[count,'ROI'] = jnk.iloc[0]['ROI']
            jdf.loc[count,'Species'] = jnk.iloc[0]['Species']
            jnk = jnk[jnk.gene_symbol.isin(pivoted.columns)]
             # first drop duplicates
            dups = []
            catch = []
            for ind,row in jnk.iterrows():
                x = row['gene_symbol']
                if x in catch:
                    dups.append(ind)
                else:
                    catch.append(x)
            jnk.drop(dups,axis=0,inplace=True)
            jnk.index = jnk.gene_symbol.values
            jnk = jnk.loc[rarr]
            # find PLS expression for each component
            npcatfm = pcamod.transform(jnk['value'].values.reshape(1,-1))
            tfmx = pls_mod.transform(npcatfm)
            for c in range(1,4):
                jdf.loc[count,'C%s_exp'%c] = tfmx[0,c-1]
            
            count+=1
            #catch.append(jnk)
    
    # calculate similarity
    # same code as above, just now embedded in the loop
    print('calculating similarity')
    
    for name, div in mapper.items():
        jdf.loc[jdf[jdf.ROI.isin(div)].index,'MacroStructure'] = name
        
    jpdfs = {}
    for i in range(1,4):
        jpdf = jdf[['ID','C%s_exp'%i,'MacroStructure']
                      ].set_index(['ID'],append=True
                                 ).pivot_table(index='ID',
                                               columns='MacroStructure',
                                               values='C%s_exp'%i)
        for ind,row in jpdf.iterrows():
            n_valid = len([x for x in row.values if pandas.notnull(x)])
            jpdf.loc[ind,'n_valid'] = n_valid
        jpdfs.update({i: jpdf})
    
    for c in range(1,4):
        cjdf = jpdfs[c]
        aba = pandas.read_csv('data/GCorr_BSComp_ABA_C%s_data.csv'%c,
                           index_col=0)
        aba.columns = ['ABA_mean','ABA_sem']
        aba = aba.loc[cjdf.columns[:-1]]
        for i,row in cjdf.iterrows():
            forcorr = pandas.DataFrame(aba,copy=True)
            if row['n_valid'] > 4:
                forcorr.loc[:,'gvec'] = row.values[:-1]
                forcorr.dropna(inplace=True)
                r = stats.pearsonr(forcorr['ABA_mean'].values,
                                  forcorr['gvec'].values)[0]
                rho = stats.spearmanr(forcorr['ABA_mean'].values,
                                  forcorr['gvec'].values)[0]
                cjdf.loc[i,'C%s_r'%c] = r
                cjdf.loc[i,'C%s_rho'%c] = rho
    
    cols = ['ID', 'Species',]
    jsum = pandas.DataFrame(jpdfs[1].index)
    for col in cols:
        jsum.loc[:,col] = jdf.groupby('ID')[col].first().values
    for c in range(1,4):
        jsum.loc[:,'C%s_r'%c] = jpdfs[c].loc[:,'C%s_r'%c].values
        jsum.loc[:,'C%s_rho'%c] = jpdfs[c].loc[:,'C%s_rho'%c].values
        jsum.loc[:,'n_valid'] = jpdfs[c].loc[:,'n_valid'].values
    # keep track of iteration
    jsum.loc[:,'iteration'] = it
    # print results to keep track of progress
    print('='*5,it,'results','='*5)
    print(jsum.groupby('Species')[['C1_r','C2_r','C3_r']].mean())
    print('_'*20)
    # store results
    results.append(jsum)
# Out:
# working on iteration 1 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 0 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.479949 -0.044480 -0.137604
# Human       0.602841 -0.449706 -0.144260
# Macaque     0.520805 -0.119107 -0.017901
# ____________________
# working on iteration 2 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 1 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.018473  0.120571 -0.310306
# Human      -0.123650  0.110713 -0.337049
# Macaque     0.095174 -0.256412 -0.089577
# ____________________
# working on iteration 3 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 2 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.440405 -0.241144 -0.049750
# Human       0.087028 -0.163853 -0.020916
# Macaque    -0.489325 -0.191923 -0.136323
# ____________________
# working on iteration 4 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 3 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.502440  0.328159 -0.524446
# Human       0.434364  0.116156 -0.520951
# Macaque     0.273663  0.208050 -0.311057
# ____________________
# working on iteration 5 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 4 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.050267  0.148485 -0.133033
# Human       0.485720  0.140729 -0.232883
# Macaque    -0.206141 -0.132873 -0.089425
# ____________________
# working on iteration 6 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 5 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.429342 -0.033759  0.133418
# Human       0.434222 -0.294890  0.004057
# Macaque     0.015300 -0.150370  0.266129
# ____________________
# working on iteration 7 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 6 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.579372 -0.533860  0.407378
# Human      -0.516156 -0.464425  0.010215
# Macaque    -0.422153 -0.728043 -0.008963
# ____________________
# working on iteration 8 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 7 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.407984 -0.336480  0.204670
# Human       0.622675 -0.062607 -0.198426
# Macaque     0.638893 -0.175749  0.212377
# ____________________
# working on iteration 9 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 8 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.055560  0.245740  0.104593
# Human       0.030076  0.376675 -0.314175
# Macaque    -0.030510  0.204260 -0.369290
# ____________________
# working on iteration 10 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 9 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.578617 -0.239749  0.354458
# Human      -0.424008 -0.222696  0.018350
# Macaque    -0.466018 -0.214523  0.107661
# ____________________
# working on iteration 11 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 10 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.257391  0.247647  0.076213
# Human      -0.275080  0.256770  0.088656
# Macaque    -0.161391  0.556844  0.071857
# ____________________
# working on iteration 12 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 11 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.223862  0.100192 -0.121289
# Human       0.289289  0.069380 -0.184548
# Macaque     0.068656 -0.077118 -0.246309
# ____________________
# working on iteration 13 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 12 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.183534  0.642161 -0.304472
# Human      -0.379732  0.558868 -0.391025
# Macaque    -0.140736  0.406489 -0.324500
# ____________________
# working on iteration 14 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 13 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.240580  0.481703  0.156183
# Human      -0.345905  0.005370  0.093452
# Macaque    -0.110570  0.184676  0.153952
# ____________________
# working on iteration 15 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 14 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.034414 -0.152458  0.149746
# Human      -0.004219 -0.142565  0.140185
# Macaque    -0.030945 -0.172167  0.110266
# ____________________
# working on iteration 16 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 15 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.463182  0.079238  0.210068
# Human      -0.179483  0.436450 -0.120557
# Macaque    -0.387874 -0.039091 -0.168570
# ____________________
# working on iteration 17 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 16 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.205521  0.148267 -0.414598
# Human      -0.165317  0.338447 -0.337742
# Macaque     0.073408  0.094840 -0.484072
# ____________________
# working on iteration 18 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 17 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.396887 -0.417629  0.302215
# Human      -0.228833 -0.323746 -0.186339
# Macaque    -0.280328 -0.481747 -0.013064
# ____________________
# working on iteration 19 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 18 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.429438 -0.112363  0.163779
# Human      -0.683931 -0.271588  0.143574
# Macaque    -0.432634 -0.047589 -0.016203
# ____________________
# working on iteration 20 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 19 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.497351  0.302182 -0.032667
# Human       0.463319  0.076855 -0.248985
# Macaque    -0.543725  0.180209 -0.364319
# ____________________
# working on iteration 21 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 20 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.665124 -0.252382 -0.419075
# Human      -0.698124 -0.280359 -0.331045
# Macaque    -0.708740 -0.257744 -0.365477
# ____________________
# working on iteration 22 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 21 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.595178  0.669844  0.576781
# Human      -0.520115  0.552206  0.263394
# Macaque    -0.501157  0.713720  0.353474
# ____________________
# working on iteration 23 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 22 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.366255  0.459746  0.349929
# Human      -0.562104  0.491337  0.000261
# Macaque    -0.274256  0.452120  0.096966
# ____________________
# working on iteration 24 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 23 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.396417  0.336013  0.053172
# Human      -0.308919  0.382300 -0.029250
# Macaque    -0.230801  0.484350  0.117443
# ____________________
# working on iteration 25 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 24 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.501592 -0.313673 -0.359293
# Human      -0.443992 -0.506539 -0.180978
# Macaque    -0.214485 -0.334745 -0.374119
# ____________________
# working on iteration 26 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 25 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.061104  0.124091 -0.162015
# Human       0.452049  0.288645 -0.294977
# Macaque     0.180130 -0.070900 -0.133248
# ____________________
# working on iteration 27 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 26 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.579845  0.179058 -0.032241
# Human       0.633121  0.189581 -0.033698
# Macaque     0.465756 -0.186831  0.172263
# ____________________
# working on iteration 28 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 27 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.578582 -0.133674 -0.021054
# Human       0.608799  0.011919 -0.279238
# Macaque     0.110858  0.038540 -0.148026
# ____________________
# working on iteration 29 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 28 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.744845  0.384540 -0.002988
# Human      -0.453523  0.534267 -0.261786
# Macaque    -0.231363  0.224331  0.156150
# ____________________
# working on iteration 30 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 29 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.159694  0.264355 -0.214941
# Human       0.145557  0.246121 -0.122916
# Macaque    -0.275363 -0.067499 -0.034418
# ____________________
# working on iteration 31 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 30 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.495011 -0.097259  0.275813
# Human       0.357180  0.337615  0.023293
# Macaque     0.417457 -0.441204  0.210357
# ____________________
# working on iteration 32 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 31 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.531101  0.155613  0.071121
# Human       0.700995  0.268003 -0.222341
# Macaque     0.181737  0.284094 -0.215941
# ____________________
# working on iteration 33 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 32 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.009675 -0.145715 -0.058106
# Human       0.087034 -0.395266 -0.294885
# Macaque     0.106055 -0.188535 -0.108431
# ____________________
# working on iteration 34 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 33 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.278810  0.305994  0.403228
# Human      -0.505462 -0.258676  0.140074
# Macaque    -0.460470  0.228493  0.307019
# ____________________
# working on iteration 35 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 34 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.532656  0.060699  0.033509
# Human       0.664081 -0.139206 -0.180181
# Macaque     0.366156  0.193745 -0.113691
# ____________________
# working on iteration 36 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 35 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.572370  0.309530  0.236224
# Human       0.023519  0.322638 -0.043709
# Macaque    -0.214704  0.526239 -0.134139
# ____________________
# working on iteration 37 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 36 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.351772 -0.225349  0.118262
# Human       0.403280 -0.426410 -0.125629
# Macaque     0.092781 -0.163889  0.110208
# ____________________
# working on iteration 38 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 37 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.028834 -0.087421  0.484724
# Human      -0.416430 -0.199570  0.102181
# Macaque    -0.203887 -0.069444  0.281641
# ____________________
# working on iteration 39 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 38 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.142581  0.479240 -0.036746
# Human       0.144370  0.497639 -0.143049
# Macaque    -0.448991 -0.162506  0.263498
# ____________________
# working on iteration 40 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 39 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.010677 -0.031331  0.217476
# Human       0.005357  0.499297  0.060360
# Macaque     0.154109 -0.100631  0.169741
# ____________________
# working on iteration 41 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 40 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.037231 -0.371242 -0.249048
# Human      -0.161791 -0.588102 -0.121413
# Macaque    -0.378476 -0.438271  0.060445
# ____________________
# working on iteration 42 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 41 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.087897 -0.356281 -0.217012
# Human       0.329273 -0.349545 -0.244119
# Macaque     0.213618 -0.456590 -0.213777
# ____________________
# working on iteration 43 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 42 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.173058  0.413998  0.149210
# Human      -0.259802  0.272436 -0.018403
# Macaque    -0.115725  0.258433 -0.023362
# ____________________
# working on iteration 44 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 43 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.177105  0.228710 -0.120459
# Human       0.196245  0.421003 -0.177128
# Macaque     0.341762  0.236294 -0.111481
# ____________________
# working on iteration 45 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 44 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.144762 -0.436049  0.073070
# Human      -0.093566 -0.431536 -0.150689
# Macaque    -0.389724 -0.393463 -0.035592
# ____________________
# working on iteration 46 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 45 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.589390 -0.393265  0.026698
# Human       0.364291 -0.043923 -0.090849
# Macaque     0.572089 -0.221708  0.068043
# ____________________
# working on iteration 47 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 46 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.242461  0.186455  0.286018
# Human       0.106078  0.032448 -0.143403
# Macaque     0.012183  0.290908 -0.190397
# ____________________
# working on iteration 48 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 47 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.042660  0.225407 -0.538719
# Human       0.309741  0.062730 -0.292480
# Macaque     0.417481  0.283813 -0.480146
# ____________________
# working on iteration 49 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 48 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.383181  0.008909 -0.150117
# Human      -0.221668  0.292432 -0.263073
# Macaque     0.060275  0.046721 -0.370690
# ____________________
# working on iteration 50 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 49 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.759116  0.455315  0.048803
# Human       0.626696  0.388427 -0.127971
# Macaque     0.604746  0.547086 -0.037485
# ____________________
# working on iteration 51 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 50 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.397593 -0.008831 -0.256687
# Human      -0.213793 -0.027481 -0.360596
# Macaque     0.069204  0.008757 -0.129301
# ____________________
# working on iteration 52 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 51 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.082744  0.012383  0.007717
# Human      -0.045165  0.110753 -0.354339
# Macaque     0.143448  0.265618 -0.161289
# ____________________
# working on iteration 53 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 52 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.368511  0.471258  0.251254
# Human      -0.436229  0.448936 -0.056042
# Macaque    -0.474740  0.312769  0.194582
# ____________________
# working on iteration 54 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 53 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.426169 -0.019851 -0.159519
# Human       0.379777 -0.136939 -0.328852
# Macaque    -0.304555 -0.085739  0.178678
# ____________________
# working on iteration 55 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 54 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.662863  0.613701 -0.191013
# Human      -0.780602  0.599525 -0.131649
# Macaque    -0.627802  0.411863 -0.177188
# ____________________
# working on iteration 56 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 55 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.493843  0.611710  0.023370
# Human       0.401738  0.566164  0.029492
# Macaque     0.517802  0.641524 -0.037773
# ____________________
# working on iteration 57 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 56 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.473982 -0.304242 -0.139361
# Human       0.504763 -0.309688 -0.235852
# Macaque     0.486393 -0.204042 -0.224612
# ____________________
# working on iteration 58 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 57 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.582635  0.371894  0.064921
# Human       0.595239  0.245062 -0.248448
# Macaque     0.401524  0.289824 -0.169336
# ____________________
# working on iteration 59 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 58 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.459253  0.518979  0.266849
# Human       0.489773  0.457841  0.136753
# Macaque     0.439145  0.497978  0.231640
# ____________________
# working on iteration 60 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 59 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.003470 -0.448943  0.013726
# Human       0.139870 -0.252983 -0.501731
# Macaque    -0.158507 -0.350814 -0.059947
# ____________________
# working on iteration 61 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 60 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.649487  0.106076 -0.140056
# Human      -0.146840  0.286260 -0.131684
# Macaque    -0.151774  0.167103 -0.045178
# ____________________
# working on iteration 62 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 61 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.397801 -0.254662  0.143841
# Human      -0.137239 -0.442585 -0.085971
# Macaque     0.090344 -0.397532  0.026035
# ____________________
# working on iteration 63 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 62 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.322760 -0.379025 -0.118482
# Human       0.499627 -0.652265 -0.201636
# Macaque     0.375406 -0.386432 -0.122595
# ____________________
# working on iteration 64 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 63 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.019622  0.196235 -0.003583
# Human       0.256890  0.242805  0.096919
# Macaque     0.283795 -0.302768  0.119007
# ____________________
# working on iteration 65 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 64 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.271579  0.041894 -0.227554
# Human       0.373230 -0.028122 -0.305559
# Macaque     0.275721  0.028422 -0.058604
# ____________________
# working on iteration 66 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 65 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.229875  0.049445 -0.015489
# Human       0.083225 -0.379839  0.041965
# Macaque    -0.098622 -0.337727  0.032647
# ____________________
# working on iteration 67 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 66 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.021898  0.412556 -0.011420
# Human       0.245845 -0.076024 -0.069294
# Macaque     0.369634 -0.006613  0.170106
# ____________________
# working on iteration 68 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 67 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.132670  0.357918  0.236039
# Human      -0.489235  0.511187  0.099620
# Macaque    -0.223362  0.424315  0.069581
# ____________________
# working on iteration 69 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 68 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.323567  0.208590 -0.173971
# Human      -0.381324  0.206614 -0.325961
# Macaque    -0.290430  0.461951 -0.193987
# ____________________
# working on iteration 70 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 69 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.383726 -0.072459  0.376550
# Human      -0.658226  0.111247 -0.089837
# Macaque    -0.601850  0.046763  0.141334
# ____________________
# working on iteration 71 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 70 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.514777  0.229608 -0.055130
# Human       0.033820  0.224868 -0.097531
# Macaque     0.128166  0.297544 -0.162529
# ____________________
# working on iteration 72 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 71 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.337455  0.654650 -0.138604
# Human      -0.191416  0.580190 -0.196411
# Macaque    -0.174956  0.639432 -0.287157
# ____________________
# working on iteration 73 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 72 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.579212 -0.463367 -0.150354
# Human      -0.661812 -0.061683 -0.220449
# Macaque    -0.497295 -0.050010 -0.198108
# ____________________
# working on iteration 74 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 73 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.094302 -0.225690  0.112364
# Human      -0.401353  0.166921 -0.014801
# Macaque    -0.114101 -0.338458  0.016259
# ____________________
# working on iteration 75 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# ...
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 75 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.402861  0.044897 -0.237085
# Human       0.598868 -0.030168 -0.175286
# Macaque     0.219699  0.365740 -0.125242
# ____________________
# working on iteration 77 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 76 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.285893  0.097004  0.109312
# Human      -0.061398  0.294622 -0.058220
# Macaque    -0.163885  0.186973  0.142261
# ____________________
# working on iteration 78 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 77 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.459352  0.101585 -0.037419
# Human       0.282220 -0.272709 -0.213723
# Macaque    -0.290206 -0.452127 -0.119531
# ____________________
# working on iteration 79 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 78 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.460687 -0.056301  0.008953
# Human      -0.577619 -0.511285  0.063867
# Macaque    -0.463316 -0.516235  0.197517
# ____________________
# working on iteration 80 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 79 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.423611  0.225849 -0.028301
# Human      -0.238991 -0.039220 -0.053446
# Macaque    -0.397552  0.001681 -0.028256
# ____________________
# working on iteration 81 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 80 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.127986  0.097314 -0.156783
# Human       0.097839  0.353462 -0.125570
# Macaque    -0.089483  0.201414 -0.017188
# ____________________
# working on iteration 82 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 81 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.318628 -0.337019  0.222367
# Human      -0.356046 -0.045725 -0.016985
# Macaque    -0.533555 -0.604121  0.165496
# ____________________
# working on iteration 83 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 82 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.361344 -0.582356  0.248596
# Human       0.511336 -0.449621 -0.009468
# Macaque     0.359395 -0.346156 -0.062001
# ____________________
# working on iteration 84 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 83 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.210329  0.283114  0.010491
# Human       0.212604 -0.047357 -0.068196
# Macaque     0.151688  0.204784 -0.073741
# ____________________
# working on iteration 85 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 84 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.579900  0.593990  0.069949
# Human      -0.628786  0.609374 -0.126563
# Macaque    -0.567811  0.407607 -0.166630
# ____________________
# working on iteration 86 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 85 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.221520  0.191127 -0.137100
# Human       0.198762  0.379509 -0.334460
# Macaque     0.026079  0.029669 -0.202633
# ____________________
# working on iteration 87 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 86 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.318339 -0.096619 -0.364081
# Human      -0.394276 -0.101741 -0.256536
# Macaque    -0.389024 -0.107382 -0.301437
# ____________________
# working on iteration 88 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 87 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.113082 -0.078565 -0.052112
# Human       0.213571  0.392580 -0.193125
# Macaque    -0.189395  0.023640 -0.013668
# ____________________
# working on iteration 89 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 88 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.524348 -0.244335  0.039861
# Human      -0.426850 -0.365861  0.007544
# Macaque    -0.115183 -0.231857 -0.095915
# ____________________
# working on iteration 90 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 89 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.330639 -0.285379  0.103306
# Human      -0.088149 -0.424052 -0.131687
# Macaque    -0.076632 -0.548017 -0.018080
# ____________________
# working on iteration 91 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 90 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.465503  0.711380 -0.290857
# Human      -0.680754  0.599985 -0.420194
# Macaque    -0.299887  0.319133 -0.008659
# ____________________
# working on iteration 92 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 91 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.029836 -0.277066 -0.279059
# Human      -0.425370 -0.068191 -0.359423
# Macaque    -0.409790 -0.240323 -0.324047
# ____________________
# working on iteration 93 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 92 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.707122 -0.126604  0.026917
# Human       0.726026 -0.276695  0.042773
# Macaque     0.664727  0.252999  0.251279
# ____________________
# working on iteration 94 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 93 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.082842  0.188814 -0.332661
# Human       0.292426  0.337639 -0.086217
# Macaque    -0.439025 -0.047279 -0.216705
# ____________________
# working on iteration 95 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 94 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.328100  0.617934 -0.098770
# Human      -0.213092  0.476725  0.084025
# Macaque    -0.503460  0.470314 -0.079829
# ____________________
# working on iteration 96 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 95 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.299975  0.140466 -0.300641
# Human      -0.420198 -0.120524 -0.286417
# Macaque    -0.175988 -0.098665 -0.290333
# ____________________
# working on iteration 97 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 96 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.472316  0.087338  0.202194
# Human      -0.298855 -0.071537 -0.208785
# Macaque    -0.179964 -0.197366 -0.065957
# ____________________
# working on iteration 98 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 97 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.180621  0.189491 -0.401331
# Human       0.119347  0.233263 -0.307602
# Macaque    -0.061706 -0.081752 -0.227058
# ____________________
# working on iteration 99 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 98 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.667300  0.016146  0.156487
# Human      -0.477490 -0.251544  0.190417
# Macaque    -0.210255 -0.096503 -0.025406
# ____________________
# working on iteration 100 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 99 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.442194  0.187938  0.242326
# Human      -0.403454  0.532226  0.139667
# Macaque    -0.161158  0.219436  0.008424
# ____________________

# %%
# concatenate results
randos = pandas.concat(results)

# %%
# save it, so you don't have to run that whole thing again
#randos.to_csv('./data/random_mats.csv')

# %%
# load it if necessary
# randos = pandas.read_csv('./data/random_mats.csv',index_col=0)

# %%
# build it into a summarized dataframe
randos.loc[:,'ind'] = range(len(randos)) 
rtall = randos.melt('ind',['C1_r','C2_r','C3_r'],'component','expr')
rtall.loc[:,'Species'] = ['%s_Null'%x for x in randos.Species] * 3
rtall.loc[:,'Species2'] = [x for x in randos.Species] * 3
rtall.loc[:,'ID'] = [x for x in randos.ID] * 3

# %%
# concatenate it with the "true" results for comparison
vtall = pandas.concat([tall,rtall])

# %%
# set some colors
pal = [sns.color_palette('cividis')[-2],
       sns.color_palette('viridis')[-2],
       sns.color_palette('magma')[-2]]

# %%
# plot the null distributions as violin plots over the boxplots from 
# earlier. NOTE: this aggregates null distributions across donors
# which doesn't make that much sense, as each donor has different data
# and therefore has their own unique null.
sns.swarmplot(x='component',y='expr',hue='Species',data=tall,dodge=True,palette=pal)
sns.boxplot(x='component',y='expr',hue='Species',data=tall,color='gray')
plt.ylabel('Correlation w/ ABA Component')
g = sns.violinplot(x='component',y='expr',hue='Species2',data=rtall,color='gray')
plt.ylabel('Correlation w/ ABA Component')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
g.set_xticklabels(['C1','C2','C3'])
# plt.savefig(os.path.join(figdir,'XSpecies_null_simple.pdf'),
#            bbox_inches='tight')
# Out:
# [Text(0, 0, 'C1'), Text(1, 0, 'C2'), Text(2, 0, 'C3')]

# %% [markdown]
# To overcome the *note* above, I wanted to plot the individual level null distributions against the "true" values.

# %%
tall.loc[:,'ID'] = subsum.ID.tolist() * 3

# %%
plt.subplots(figsize=(12,8))
sns.stripplot(x='ID',y='expr',hue='component',data=tall,
              palette=pal,dodge=True,s=15)
g = sns.violinplot(x='ID',y='expr',data=rtall,color='gray',cut=0,
                   hue='component')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
g.set_xticklabels(subsum.Species.tolist(),rotation=90)
plt.xlabel('Donor')
plt.ylabel('Regional Correlation to \nABA Expression (r)')
# plt.savefig(os.path.join(figdir,'XSpecies_null_indiv.pdf'),
#            bbox_inches='tight')

# %%
# generate exact p-values for each subject
for i,row in subsum.iterrows():
    for c in range(1,4):
        null = randos[randos.ID==row['ID']]['C%s_r'%c].sort_values().values
        val = row['C%s_r'%c]
        p = len(null[null>val]) / len(null)
        subsum.loc[i,'C%s_p(r)'%c] = p

# %% [markdown]
# # PC comparison

# %% [markdown]
# Okay, so these are almost all significant for all components. Not terribly surprising. But, there is maybe another null model necessary. One might just point out that perhaps the overall brain gene expression patterns across species is highly similar, and that any biological signal will be highly reproducible across datasets. So, here we want to set up a distribution of r-values (representing reproducibility) for other biologically meaningful signals, to see how common it is to demonstrate a reproducible regional expression pattern across these datasets.
#
# The easiest way to drum up a bunch of biological signals is probably to use the AHBA prinicipal components. So, we'll create a distribution of r-values across AHBA PCs, and compare our PLS Component r-values to this distribution

# %%
pcdiv = pandas.read_csv('./data/Allen_Macrostructure_PCs.csv',index_col = 0)

# %%
pcs = pandas.read_csv('./data/Allen_PC_matrix.csv',index_col = 0)

# %%
# this is pretty much the same code as above, but adapted to use the
# Allen PCs rather than scrambled data
print('calculating PC expression')
jdf = pandas.DataFrame(columns = pcs.columns)
catch = []
count = 0
for i,ID in enumerate(df.ID.unique()):
    print('working on %s of 16'%(i+1))
    for region in df.ROI.unique():
        jnk = pandas.DataFrame(df[(df.ROI==region) & (df.ID==ID)],copy=True)
        if jnk.shape[0] == 0: continue
        jdf.loc[count,'ID'] = jnk.iloc[0]['ID']
        jdf.loc[count,'ROI'] = jnk.iloc[0]['ROI']
        jdf.loc[count,'Species'] = jnk.iloc[0]['Species']
        jnk.index = jnk.gene_symbol.values
        jnk = jnk.loc[shared]
        jdf.loc[count,pcs.columns] = np.dot(jnk['value'].values,pcs.loc[jnk.index].values)
        count+=1
        #catch.append(jnk)

# calculate similarity
print('calculating similarity')
for name, div in mapper.items():
    jdf.loc[jdf[jdf.ROI.isin(div)].index,'MacroStructure'] = name

# stupid value conversion
jnk = pandas.DataFrame(pandas.to_numeric(jdf[pcs.columns].values.flat,
                                          ).reshape(len(jdf),len(pcs.columns)),
                      index = jdf,columns=pcs.columns)
for col in [x for x in jdf.columns if x not in jnk.columns]:
    jnk.loc[:,col] = jdf[col].values
jdf = jnk

jpdfs = {}
for pc in pcs.columns:
    jpdf = jdf[['ID',pc,'MacroStructure']
                  ].set_index(['ID'],append=True
                             ).pivot_table(index='ID',
                                           columns='MacroStructure',
                                           values=pc)
    #gpdf.drop('GangEm',axis=1,inplace=True)
    for ind,row in jpdf.iterrows():
        n_valid = len([x for x in row.values if pandas.notnull(x)])
        jpdf.loc[ind,'n_valid'] = n_valid
    jpdfs.update({pc: jpdf})

for c in pcs.columns:
    cjdf = jpdfs[c]
    aba = pandas.DataFrame(pcdiv['P%s'%c])
    aba = aba.loc[cjdf.columns[:-1]]
    for i,row in cjdf.iterrows():
        forcorr = pandas.DataFrame(aba,copy=True)
        if row['n_valid'] > 4:
            forcorr.loc[:,'gvec'] = row.values[:-1]
            forcorr.dropna(inplace=True)
            r = stats.pearsonr(forcorr['P%s'%c].values,
                              forcorr['gvec'].values)[0]
            rho = stats.spearmanr(forcorr['P%s'%c].values,
                              forcorr['gvec'].values)[0]
            cjdf.loc[i,'%s_r'%c] = r
            cjdf.loc[i,'%s_rho'%c] = rho

cols = ['ID', 'Species',]
jsum = pandas.DataFrame(jpdfs[list(jpdfs.keys())[0]].index)
for col in cols:
    jsum.loc[:,col] = jdf.groupby('ID')[col].first().values
for c in pcs.columns:
    jsum.loc[:,'%s_r'%c] = jpdfs[c].loc[:,'%s_r'%c].values
    jsum.loc[:,'%s_rho'%c] = jpdfs[c].loc[:,'%s_rho'%c].values
    jsum.loc[:,'n_valid'] = jpdfs[c].loc[:,'n_valid'].values
# Out:
# calculating PC expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity

# %%
subsum.groupby('Species').mean()
# Out:
#                 C1_r    C1_rho   n_valid      C2_r    C2_rho      C3_r  \
# Species
# Chimpanzee  0.943123  0.965714  8.800000  0.872043  0.874286  0.631712
# Human       0.950907  0.965476  8.833333  0.863397  0.883333  0.764530
# Macaque     0.930545  0.932857  8.600000  0.886409  0.809048  0.675524
#
#               C3_rho   ind
# Species
# Chimpanzee  0.681429   8.0
# Human       0.728571   2.5
# Macaque     0.641905  13.0

# %%
# now let't melt that df
jsum.loc[:,'ind'] = range(len(jsum))
jtall = jsum.melt('ind',[x for x in jsum.columns if '_r' in x and 'ho' not in x],
                  'component','expr')
jtall.loc[:,'Species'] = jsum.Species.tolist() * len(pcs.columns)
jtall.loc[:,'ID'] = jsum.ID.tolist() * len(pcs.columns)

jtall.loc[:,'c'] = [int(x.split('C')[1].split('_')[0]) for x in jtall.component.values]

# %%
# generating p-values
comps = pandas.DataFrame(index=jsum.ID.values)
for i,row in jsum.iterrows():
    ID = row['ID']
    dist = row[[x for x in jsum.columns if '_r' in x and 'ho' not in x]].values
    for c in range(1,4):
        val = subsum[subsum.ID==ID]['C%s_r'%c].values[0]
        p = len(dist[dist>val]) / 100
        
        comps.loc[ID,'C%s'%c] = p
    sig = sorted(dist)[95]
    comps.loc[ID,'sig'] = sig

# %%
# having a look
comps
# Out:
#            C1   C2    C3       sig
# HSB123R  0.00  0.0  0.01  0.608528
# HSB126R  0.00  0.0  0.00  0.602219
# HSB130L  0.00  0.0  0.00  0.550936
# HSB135R  0.00  0.0  0.00  0.455539
# HSB136R  0.00  0.0  0.02  0.643673
# HSB145R  0.00  0.0  0.03  0.645330
# PTB162L  0.00  0.0  0.03  0.618337
# PTB164R  0.00  0.0  0.19  0.701190
# PTB165R  0.00  0.0  0.05  0.712459
# PTB166R  0.00  0.0  0.02  0.567531
# PTB167R  0.00  0.0  0.02  0.524914
# RMB160L  0.01  0.0  0.04  0.606964
# RMB161L  0.00  0.0  0.01  0.621674
# RMB196R  0.00  0.0  0.05  0.643773
# RMB218L  0.00  0.0  0.00  0.526090
# RMB219L  0.00  0.0  0.00  0.629625

# %%
# And now we plot the "null" distribution, along with the "true"
# r-values of the PLS Components
sns.stripplot(x='ID',y='expr',hue='component',data=tall,palette=pal)
g = sns.violinplot(x='ID',y='expr',data=jtall,color='gray',cut=0)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
count = 0
for i,row in comps.iterrows():
    plt.plot([(count-0.3),(count+0.3)],[row['sig'],row['sig']],ls='--',c='k')
    count+=1
g.set_xticklabels(subsum.Species.tolist(),rotation=90)
plt.xlabel('Donor')
plt.ylabel('Regional Correlation to \nABA Expression (r)')
# plt.savefig(os.path.join(figdir,'XSpecies_signull_indiv.pdf'),
#            bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Regional Correlation to \nABA Expression (r)')
