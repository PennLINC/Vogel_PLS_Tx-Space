# %%
import os
import pandas
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits as mplot3d
import seaborn as sns
from copy import deepcopy
from scipy import stats
from matplotlib.colors import Normalize
from statsmodels.stats.multitest import multipletests
from sklearn.preprocessing import MinMaxScaler
# Out:
# /Users/jacobv/pls_gxp/lib/python3.7/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# # TO-DO
# * Add PEC_nhp_melt spreadsheet to data
# * Add PC_matrix dataset?
# * Change paths

# %% [markdown]
# # Prep data

# %% [markdown]
# ### Instructions
# Add information about
# * Source of data paper and where it was downloaded
# * any script necessary to make it
# * what's in it!

# %%
df = pandas.read_csv('/Users/jacobv/Science/PLS_GXP/XSpecies/PEC_nhp_melt.csv')

# %% [markdown]
# First we want to harmonize the dataset with Allen and pull out the PLS Components for each of the samples here

# %%
df.loc[:,'gene_symbol'] = [x.split('|')[-1] for x in df.ProbeID.values]

# %%
# !! CHANGE PATH. PUT REFERENCE TO OTHER NOTEBOOK !!
allcomps = pandas.read_csv('/Users/jacobv/Science/PLS_GXP/all_comps.csv',index_col=0)
allcomps.index = allcomps.gene_symbol.values
allcomps.columns = ['C1','gene_symbol','gene_name','C2','C3']
allcomps.head()
# Out:
#                 C1 gene_symbol                     gene_name        C2  \
# A1BG      0.001627        A1BG        alpha-1-B glycoprotein  0.004287
# A1BG-AS1 -0.006209    A1BG-AS1                           NaN -0.007689
# A2M       0.004887         A2M         alpha-2-macroglobulin  0.008449
# A2ML1    -0.008090       A2ML1  alpha-2-macroglobulin-like 1 -0.003317
# A3GALT2  -0.001231     A3GALT2                           NaN  0.000859
#
#                 C3
# A1BG     -0.021919
# A1BG-AS1 -0.003631
# A2M       0.003676
# A2ML1    -0.009593
# A3GALT2   0.000137

# %%
# find common genes across datasets
shared = set(df.gene_symbol.values) & set(allcomps.index)

# %%
# crop to shared genes
df = df[df.gene_symbol.isin(shared)]

# %% [markdown]
# Here, we're calculating the PLS Component expression for each component for each human and primate tissue sample available.

# %%
# There is surely a faster way of doing this but I was lazy.
# Took awhile to run on my computer

gdf = pandas.DataFrame()
count = 0
# for each subject
for i,ID in enumerate(df.ID.unique()):
    print('working on %s of 16'%(i+1))
    # for each region
    for region in df.ROI.unique():
        # pull out relevant data
        jnk = pandas.DataFrame(df[(df.ROI==region) & (df.ID==ID)],copy=True)
        if jnk.shape[0] == 0: continue # skip if region missing
        # add info to new spreadsheet
        gdf.loc[count,'ID'] = jnk.iloc[0]['ID']
        gdf.loc[count,'ROI'] = jnk.iloc[0]['ROI']
        gdf.loc[count,'Species'] = jnk.iloc[0]['Species']
        # prep for dot product (aka the "prediction")
        jnk.index = jnk.gene_symbol.values
        jnk = jnk.loc[shared]
        # find PLS expression for each component
        for c in range(1,4):
            gdf.loc[count,'C%s_exp'%c] = np.dot(jnk['value'].values,
                                             allcomps.loc[jnk.index,'C%s'%c].values)
        count+=1
# Out:
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16

# %%
# Might want to save that so you don't have to do it again

#gdf.to_csv('/Users/jacobv/Science/PLS_GXP/XSpecies/PEC_nhp_indiv_withCs.csv')

# %%
# And load it to start from here
# gdf = pandas.read_csv('/Users/jacobv/Science/PLS_GXP/XSpecies/PEC_nhp_indiv_withCs.csv',
#                      index_col=0)

# %%
# list the regions in the dataset
gdf.ROI.value_counts()
# Out:
# HIP    16
# ITC    16
# S1C    16
# AMY    16
# VFC    16
# STC    16
# OFC    16
# IPC    16
# DFC    15
# A1C    15
# STR    15
# M1C    15
# MD     15
# V1C    15
# CBC    15
# MFC    14
# Name: ROI, dtype: int64

# %%
# map each region to one of the AHBA regions
mapper = {'Sensorimotor': ['S1C','M1C'],
          'Limbic': ['HIP','AMY'],
          'Cerebellum': ['CBC'],
          'Forebrain': ['NAC'],
          'Striatum': ['STR'],
          'Frontal': ['OFC','VFC','DFC','MFC'],
          'Temporal': ['STC','A1C'],
          'Parietal': ['IPC','ITC'],
          'Occipital': ['V1C'],
          'Thalamus': ['MD']
         }
for name, div in mapper.items():
    gdf.loc[gdf[gdf.ROI.isin(div)].index,'MacroStructure'] = name

# %%
# remove outliers
gdf.drop([1099,777],inplace=True)

# %% [markdown]
# # Visualization (for fun)
# For fun, we can visualize the dispersion of smaples across components

# %%
sns.set_context('notebook',font_scale=1.5)

# for each species separately
for species in gdf.Species.unique():
    if not pandas.notnull(species): continue
    print(species)
    adf = gdf[gdf.Species==species]
    # get means and sds across donors
    means = adf.groupby('MacroStructure')[['C1_exp','C2_exp','C3_exp']].mean()
    stds = adf.groupby('MacroStructure')[['C1_exp','C2_exp','C3_exp']].std()
    stds.columns = ['C1_sd','C2_sd','C3_sd']
    # set up plotting dataframe for easy reference
    plotr = pandas.concat([means,stds],axis=1)
    plotr.loc[:,'region'] = plotr.index
    # start building plot
    ax = plt.axes(projection='3d')
    # plot confidence intervals across all three dimensions
    for i,row in plotr.iterrows():
        c1_mn = row['C1_exp']
        c2_mn = row['C2_exp']
        c3_mn = row['C3_exp']
        c1_sd = row['C1_sd']
        c2_sd = row['C2_sd']
        c3_sd = row['C3_sd']
        ax.plot3D([c1_mn-c1_sd,c1_mn+c1_sd], [c2_mn,c2_mn], [c3_mn,c3_mn], 'gray')
        ax.plot3D([c1_mn,c1_mn], [c2_mn-c2_sd,c2_mn+c2_sd], [c3_mn,c3_mn], 'gray')
        ax.plot3D([c1_mn,c1_mn], [c2_mn,c2_mn], [c3_mn-c3_sd,c3_mn+c3_sd], 'gray')
    # plot markers
    ax.scatter3D(plotr.C1_exp, plotr.C2_exp, plotr.C3_exp, c=range(len(plotr)),cmap='tab10',
                s=100)
    # decorate
    plt.xlabel('C1')
    plt.ylabel('C2')
    ax.set_zlabel('C3')
    ax.set_xticklabels(['' for x in ax.get_xticklabels()])
    ax.set_yticklabels(['' for x in ax.get_yticklabels()])
    ax.set_zticklabels(['' for x in ax.get_zticklabels()])
    ax.set_title(species)
    plt.show()
# Out:
# Human
# /Users/jacobv/pls_gxp/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/jacobv/pls_gxp/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/jacobv/pls_gxp/lib/python3.7/site-packages/ipykernel_launcher.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator
# Chimpanzee
# Macaque

# %% [markdown]
# # Calculate reproduction of PLS Components
# Here we are using the same logic we did in the `C_GTExWorkup.ipynb` and `C_BrainSpanValidation.ipynb` notebooks. We are seeing how well the PLS Components trained in AHBA replicate in *individuals* across these three datasets. Importantly, two of the datasets are non-human primates, which include data from macaques and chimps, respectively

# %% [markdown]
# The code below is copied (and adapted) from code used in `C_GTExWorkup.ipynb` and `C_BrainSpanValidation.ipynb`, so see these notebooks for more thorough documentation

# %%
gpdfs = {}
for i in range(1,4):
    gpdf = gdf[['ID','C%s_exp'%i,'MacroStructure']
                  ].set_index(['ID'],append=True
                             ).pivot_table(index='ID',
                                           columns='MacroStructure',
                                           values='C%s_exp'%i)
    #gpdf.drop('GangEm',axis=1,inplace=True)
    for ind,row in gpdf.iterrows():
        n_valid = len([x for x in row.values if pandas.notnull(x)])
        gpdf.loc[ind,'n_valid'] = n_valid
    gpdfs.update({i: gpdf})

# %%
for c in range(1,4):
    cdf = gpdfs[c]
    aba = pandas.read_csv('data/GCorr_BSComp_ABA_C%s_data.csv'%c,
                       index_col=0)
    aba.columns = ['ABA_mean','ABA_sem']
    aba = aba.loc[cdf.columns[:-1]]
    for i,row in cdf.iterrows():
        forcorr = pandas.DataFrame(aba,copy=True)
        if row['n_valid'] > 4:
            forcorr.loc[:,'gvec'] = row.values[:-1]
            forcorr.dropna(inplace=True)
            r = stats.pearsonr(forcorr['ABA_mean'].values,
                              forcorr['gvec'].values)[0]
            rho = stats.spearmanr(forcorr['ABA_mean'].values,
                              forcorr['gvec'].values)[0]
            cdf.loc[i,'C%s_r'%c] = r
            cdf.loc[i,'C%s_rho'%c] = rho

# %%
cols = ['ID', 'Species',]
subsum = pandas.DataFrame(gpdfs[1].index)
for col in cols:
    subsum.loc[:,col] = gdf.groupby('ID')[col].first().values
for c in range(1,4):
    subsum.loc[:,'C%s_r'%c] = gpdfs[c].loc[:,'C%s_r'%c].values
    subsum.loc[:,'C%s_rho'%c] = gpdfs[c].loc[:,'C%s_rho'%c].values
    subsum.loc[:,'n_valid'] = gpdfs[c].loc[:,'n_valid'].values

# %% [markdown]
# Now that we have the individual level correlations to AHBA components across all individuals and species, let's plot them!

# %%
# Melt the dataset for easier plotting
subsum.loc[:,'ind'] = range(len(subsum))
tall = subsum.melt('ind',['C1_r','C2_r','C3_r'],'component','expr')
tall.loc[:,'Species'] = subsum.Species.tolist() * 3

# %%
# Plot
sns.swarmplot(x='component',y='expr',hue='Species',data=tall,dodge=True)
sns.boxplot(x='component',y='expr',hue='Species',data=tall,color='gray')
plt.ylabel('Correlation w/ ABA Component')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# What's up with that one outlier macaque?

# %%
tall[tall.expr<0.5]
# Out:
#     ind component      expr  Species
# 15   15      C1_r  0.390780  Macaque
# 47   15      C3_r  0.429357  Macaque

# %%
gdf[gdf.ID=='RMB219L'].MacroStructure.value_counts()
# Out:
# Frontal         4
# Limbic          2
# Sensorimotor    2
# Parietal        2
# Striatum        1
# Temporal        1
# Occipital       1
# Name: MacroStructure, dtype: int64

# %% [markdown]
# So this subject's correlation is worse because no subcortical or cerebellar data. Very interesting. Also interesting this didn't seem to affect the data for C2

# %% [markdown]
# # Null model

# %% [markdown]
# These correlations are all really high, and I think it's natural to wonder if the data guarantees a high correlation. So, in order to test if the within-subject r-values are greater than chance given the data, and to extract exact p-values, we'll do a bit of null modeling.

# %%
n_iter = 100 # number of iterations, 100 should be fine for now
results = []

# for each iteration
for it in range(n_iter):
    # do shuffle
    print('working on iteration',(it+1),'of',n_iter)
    print('calculating random expression')
    randies = {}
    # for each component
    for c in range(1,4):
        # set the random state
        prng = np.random.RandomState(123+it)
        # shuffle the gene expression data
        arr = allcomps.loc[shared,'C%s'%c]
        rarr = prng.choice(arr.values,len(arr),replace=False)
        rarr = pandas.Series(rarr,index=arr.index)
        randies.update({c:rarr})
    # prep a null results data frame
    jdf = pandas.DataFrame()
    catch = []
    count = 0
    # run same code as above to go through each subject and region
    for i,ID in enumerate(df.ID.unique()):
        print('working on %s of 16'%(i+1))
        for region in df.ROI.unique():
            jnk = pandas.DataFrame(df[(df.ROI==region) & (df.ID==ID)],copy=True)
            if jnk.shape[0] == 0: continue
            jdf.loc[count,'ID'] = jnk.iloc[0]['ID']
            jdf.loc[count,'ROI'] = jnk.iloc[0]['ROI']
            jdf.loc[count,'Species'] = jnk.iloc[0]['Species']
            jnk.index = jnk.gene_symbol.values
            jnk = jnk.loc[shared]
            # apply PLS weights to randomly shuffled data
            for c in range(1,4):
                jdf.loc[count,'C%s_exp'%c] = np.dot(jnk['value'].values,
                                                 randies[c].loc[jnk.index].values)
            count+=1
            #catch.append(jnk)
    
    # calculate similarity
    # same code as above, just now embedded in the loop
    print('calculating similarity')
    
    for name, div in mapper.items():
        jdf.loc[jdf[jdf.ROI.isin(div)].index,'MacroStructure'] = name
        
    jpdfs = {}
    for i in range(1,4):
        jpdf = jdf[['ID','C%s_exp'%i,'MacroStructure']
                      ].set_index(['ID'],append=True
                                 ).pivot_table(index='ID',
                                               columns='MacroStructure',
                                               values='C%s_exp'%i)
        for ind,row in jpdf.iterrows():
            n_valid = len([x for x in row.values if pandas.notnull(x)])
            jpdf.loc[ind,'n_valid'] = n_valid
        jpdfs.update({i: jpdf})
    
    for c in range(1,4):
        cjdf = jpdfs[c]
        aba = pandas.read_csv('data/GCorr_BSComp_ABA_C%s_data.csv'%c,
                           index_col=0)
        aba.columns = ['ABA_mean','ABA_sem']
        aba = aba.loc[cjdf.columns[:-1]]
        for i,row in cjdf.iterrows():
            forcorr = pandas.DataFrame(aba,copy=True)
            if row['n_valid'] > 4:
                forcorr.loc[:,'gvec'] = row.values[:-1]
                forcorr.dropna(inplace=True)
                r = stats.pearsonr(forcorr['ABA_mean'].values,
                                  forcorr['gvec'].values)[0]
                rho = stats.spearmanr(forcorr['ABA_mean'].values,
                                  forcorr['gvec'].values)[0]
                cjdf.loc[i,'C%s_r'%c] = r
                cjdf.loc[i,'C%s_rho'%c] = rho
    
    cols = ['ID', 'Species',]
    jsum = pandas.DataFrame(jpdfs[1].index)
    for col in cols:
        jsum.loc[:,col] = jdf.groupby('ID')[col].first().values
    for c in range(1,4):
        jsum.loc[:,'C%s_r'%c] = jpdfs[c].loc[:,'C%s_r'%c].values
        jsum.loc[:,'C%s_rho'%c] = jpdfs[c].loc[:,'C%s_rho'%c].values
        jsum.loc[:,'n_valid'] = jpdfs[c].loc[:,'n_valid'].values
    # keep track of iteration
    jsum.loc[:,'iteration'] = it
    # print results to keep track of progress
    print('='*5,it,'results','='*5)
    print(jsum.groupby('Species')[['C1_r','C2_r','C3_r']].mean())
    print('_'*20)
    # store results
    results.append(jsum)
# Out:
# working on iteration 1 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 0 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.109106 -0.564059  0.037033
# Human      -0.049593 -0.650273 -0.044184
# Macaque    -0.509291 -0.398273  0.208213
# ____________________
# working on iteration 2 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 1 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.563049  0.041481 -0.479247
# Human      -0.520993 -0.167423 -0.505723
# Macaque    -0.725492  0.139783 -0.256610
# ____________________
# working on iteration 3 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 2 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.391866  0.256178  0.518453
# Human       0.520008  0.136516  0.168126
# Macaque    -0.032957  0.533016  0.387493
# ____________________
# working on iteration 4 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 3 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.680758 -0.406810 -0.087795
# Human      -0.623429 -0.591756 -0.292925
# Macaque    -0.603418 -0.271198  0.055867
# ____________________
# working on iteration 5 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 4 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.171517 -0.112619  0.233660
# Human      -0.007088 -0.262423  0.234615
# Macaque    -0.695806 -0.066313  0.091529
# ____________________
# working on iteration 6 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 5 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.127889  0.121481  0.101987
# Human      -0.249905 -0.020128  0.163654
# Macaque    -0.409172  0.433206  0.274846
# ____________________
# working on iteration 7 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 6 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.182678 -0.123369  0.599726
# Human       0.251776 -0.165532  0.675517
# Macaque    -0.190264  0.331215  0.504691
# ____________________
# working on iteration 8 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 7 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.099039 -0.760251  0.647309
# Human       0.005439 -0.656160  0.096568
# Macaque    -0.455343 -0.475840  0.440052
# ____________________
# working on iteration 9 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 8 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.098622  0.059561 -0.104837
# Human      -0.134760  0.218368 -0.239458
# Macaque    -0.272857  0.395881 -0.112392
# ____________________
# working on iteration 10 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 9 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.029070  0.293122 -0.025903
# Human      -0.093728  0.406457 -0.102778
# Macaque     0.099935  0.638861 -0.300840
# ____________________
# working on iteration 11 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 10 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.538150 -0.056379 -0.230964
# Human       0.427146 -0.108701 -0.253893
# Macaque    -0.086335  0.012945 -0.050746
# ____________________
# working on iteration 12 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 11 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.136024 -0.622171 -0.020901
# Human       0.117738 -0.592796 -0.101947
# Macaque    -0.075797 -0.307513 -0.113289
# ____________________
# working on iteration 13 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 12 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.155858 -0.624098  0.213901
# Human       0.153095 -0.742577  0.245659
# Macaque    -0.081651 -0.396226  0.060604
# ____________________
# working on iteration 14 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 13 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.278923 -0.208568  0.399973
# Human       0.072845 -0.326078  0.305314
# Macaque    -0.486085  0.200945  0.091970
# ____________________
# working on iteration 15 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 14 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.084980 -0.038946  0.201676
# Human       0.085647 -0.145819  0.474712
# Macaque     0.108144  0.250085  0.252027
# ____________________
# working on iteration 16 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 15 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.166082 -0.645468  0.185141
# Human       0.025301 -0.729171  0.308124
# Macaque    -0.367505 -0.183496  0.351949
# ____________________
# working on iteration 17 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 16 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.425599 -0.491413  0.201114
# Human      -0.106650 -0.312805  0.261470
# Macaque    -0.532955  0.191772  0.391622
# ____________________
# working on iteration 18 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 17 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.489397 -0.704332 -0.426323
# Human      -0.446374 -0.642574 -0.365870
# Macaque    -0.537568 -0.127048 -0.393344
# ____________________
# working on iteration 19 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 18 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.668484 -0.471073 -0.718761
# Human      -0.464124 -0.436801 -0.581722
# Macaque    -0.707763 -0.184241 -0.565151
# ____________________
# working on iteration 20 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 19 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.491516 -0.179679 -0.662196
# Human      -0.321819 -0.227356 -0.515737
# Macaque    -0.295020 -0.011919 -0.340305
# ____________________
# working on iteration 21 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 20 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.233272 -0.650592 -0.322072
# Human      -0.061658 -0.628423 -0.393723
# Macaque    -0.450577 -0.454669 -0.252649
# ____________________
# working on iteration 22 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 21 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.213451  0.027703 -0.432836
# Human       0.300894  0.192093 -0.418743
# Macaque    -0.035160  0.266470 -0.253268
# ____________________
# working on iteration 23 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 22 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.534808 -0.266664  0.494603
# Human      -0.340491 -0.308766  0.545598
# Macaque    -0.378837  0.271903  0.435629
# ____________________
# working on iteration 24 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 23 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.283469 -0.551939  0.125718
# Human      -0.145625 -0.714528  0.035789
# Macaque    -0.245771 -0.381604 -0.009966
# ____________________
# working on iteration 25 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 24 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.325327 -0.544089 -0.521259
# Human      -0.259529 -0.569111 -0.586422
# Macaque    -0.411933 -0.014546 -0.439223
# ____________________
# working on iteration 26 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 25 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.735678 -0.217242 -0.194729
# Human      -0.452678 -0.553255  0.054033
# Macaque    -0.807088  0.092398 -0.313212
# ____________________
# working on iteration 27 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 26 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.322626 -0.297407  0.486776
# Human       0.459799 -0.350466  0.298329
# Macaque    -0.523440 -0.176550  0.295019
# ____________________
# working on iteration 28 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 27 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.088853 -0.537146 -0.001137
# Human       0.277468 -0.493889 -0.108058
# Macaque     0.003661 -0.217978 -0.045384
# ____________________
# working on iteration 29 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 28 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.099562 -0.501425  0.200076
# Human       0.085568 -0.715889  0.117715
# Macaque     0.059863 -0.295799 -0.153319
# ____________________
# working on iteration 30 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 29 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.058229 -0.319100  0.154437
# Human       0.079232 -0.400765 -0.308445
# Macaque    -0.278264  0.313831 -0.123070
# ____________________
# working on iteration 31 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 30 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.073299  0.101694  0.335334
# Human       0.170108 -0.149503  0.306138
# Macaque    -0.175986  0.501964  0.343521
# ____________________
# working on iteration 32 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 31 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.099227 -0.517667 -0.474847
# Human      -0.171187 -0.448633 -0.332039
# Macaque    -0.271724  0.052234 -0.307990
# ____________________
# working on iteration 33 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 32 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.288308 -0.510982 -0.391516
# Human      -0.476154 -0.338586 -0.370190
# Macaque    -0.469395 -0.330056 -0.090430
# ____________________
# working on iteration 34 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 33 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.521800 -0.608382 -0.476966
# Human      -0.505540 -0.825600 -0.517349
# Macaque    -0.571973 -0.340648 -0.511004
# ____________________
# working on iteration 35 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 34 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.311510 -0.488793  0.205441
# Human       0.470965 -0.379166  0.227875
# Macaque    -0.013414 -0.086177  0.153640
# ____________________
# working on iteration 36 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 35 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.175973 -0.202678 -0.299537
# Human      -0.094796  0.271429 -0.416164
# Macaque    -0.139041  0.101068 -0.148085
# ____________________
# working on iteration 37 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 36 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.499968 -0.392023  0.017383
# Human       0.432129 -0.565335  0.056445
# Macaque     0.095032  0.316555 -0.148166
# ____________________
# working on iteration 38 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 37 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.554458 -0.147796 -0.260095
# Human      -0.524831 -0.426952 -0.552577
# Macaque    -0.663323  0.098028 -0.228947
# ____________________
# working on iteration 39 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 38 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.517105 -0.198029  0.167104
# Human      -0.106125 -0.239142 -0.069030
# Macaque    -0.684912 -0.045118 -0.187556
# ____________________
# working on iteration 40 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 39 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.066518 -0.411643  0.198204
# Human       0.180524 -0.372644  0.093998
# Macaque    -0.220629  0.051438  0.100387
# ____________________
# working on iteration 41 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 40 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.552464 -0.006988  0.428706
# Human      -0.408122 -0.326465  0.339662
# Macaque    -0.400727 -0.018419  0.079198
# ____________________
# working on iteration 42 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 41 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.324146  0.040424 -0.092788
# Human      -0.183157 -0.178365 -0.263160
# Macaque    -0.344677  0.134474 -0.307561
# ____________________
# working on iteration 43 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 42 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.333842 -0.205121 -0.644160
# Human      -0.073005 -0.160154 -0.434212
# Macaque    -0.242289  0.122177 -0.644138
# ____________________
# working on iteration 44 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 43 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.187919 -0.099811  0.302511
# Human       0.374984 -0.584705 -0.014110
# Macaque     0.015637  0.238999  0.103670
# ____________________
# working on iteration 45 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 44 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.447011 -0.782664 -0.049197
# Human      -0.452179 -0.744424 -0.149234
# Macaque    -0.374545 -0.608317  0.137014
# ____________________
# working on iteration 46 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 45 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.379652 -0.450568  0.148502
# Human      -0.135330 -0.526817  0.426055
# Macaque    -0.467189 -0.402103  0.329749
# ____________________
# working on iteration 47 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 46 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.129422  0.060578 -0.400879
# Human      -0.263458  0.113466 -0.373891
# Macaque    -0.113319  0.287635 -0.301452
# ____________________
# working on iteration 48 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 47 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.472819 -0.602632 -0.117251
# Human      -0.437459 -0.424433 -0.260148
# Macaque    -0.756202 -0.380209 -0.202226
# ____________________
# working on iteration 49 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 48 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.117423 -0.179407  0.494727
# Human       0.051124 -0.314701  0.337924
# Macaque    -0.509622  0.006084  0.414413
# ____________________
# working on iteration 50 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 49 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.301973 -0.573403  0.468356
# Human      -0.483251 -0.378606  0.257776
# Macaque    -0.667320  0.092931  0.505071
# ____________________
# working on iteration 51 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 50 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.491907 -0.681719 -0.454784
# Human      -0.481635 -0.351412 -0.430372
# Macaque    -0.513447 -0.130041 -0.188771
# ____________________
# working on iteration 52 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 51 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.675615  0.370430 -0.425696
# Human      -0.376099  0.054557 -0.341418
# Macaque    -0.619058  0.387232 -0.479879
# ____________________
# working on iteration 53 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 52 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.378511  0.373829 -0.295184
# Human      -0.272396 -0.251819 -0.225613
# Macaque    -0.437705  0.344850 -0.404694
# ____________________
# working on iteration 54 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 53 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.118684  0.256220 -0.375042
# Human      -0.154349  0.100087 -0.426576
# Macaque    -0.139459  0.208586 -0.188034
# ____________________
# working on iteration 55 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 54 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.661779 -0.463402 -0.466394
# Human      -0.256441 -0.620767 -0.446941
# Macaque    -0.526932 -0.413690 -0.388761
# ____________________
# working on iteration 56 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 55 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.144367 -0.054595 -0.370319
# Human       0.104662  0.165850 -0.361481
# Macaque    -0.306835  0.252911 -0.385714
# ____________________
# working on iteration 57 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 56 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.250415  0.074201 -0.066895
# Human       0.505462  0.135263 -0.201665
# Macaque     0.360385  0.441559 -0.139715
# ____________________
# working on iteration 58 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 57 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.330802  0.029264 -0.439937
# Human      -0.290553 -0.152862 -0.364342
# Macaque    -0.321674 -0.115880 -0.381927
# ____________________
# working on iteration 59 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 58 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.529599 -0.063627 -0.032912
# Human       0.800770 -0.231472 -0.148863
# Macaque     0.134414  0.220720 -0.048893
# ____________________
# working on iteration 60 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 59 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.292340 -0.604444 -0.271300
# Human       0.529617 -0.634088 -0.240253
# Macaque     0.128911 -0.486526 -0.213559
# ____________________
# working on iteration 61 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 60 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.094092 -0.236576 -0.613964
# Human       0.312478 -0.365015 -0.584454
# Macaque     0.059364 -0.086062 -0.376506
# ____________________
# working on iteration 62 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 61 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.755908 -0.326560 -0.144587
# Human      -0.349727 -0.521091 -0.093149
# Macaque    -0.509544  0.186085  0.055861
# ____________________
# working on iteration 63 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 62 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.879588 -0.469489 -0.084670
# Human       0.805472 -0.325942 -0.033540
# Macaque     0.579342 -0.187403  0.098273
# ____________________
# working on iteration 64 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 63 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.197516 -0.375758 -0.172132
# Human       0.100761 -0.544065 -0.217193
# Macaque    -0.123963  0.004854 -0.419266
# ____________________
# working on iteration 65 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 64 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.504730 -0.059664  0.562353
# Human       0.388856 -0.231573  0.504093
# Macaque     0.224927  0.081942  0.493710
# ____________________
# working on iteration 66 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 65 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.671539  0.341436  0.352778
# Human       0.632779  0.082430  0.436201
# Macaque     0.288222  0.452242  0.315167
# ____________________
# working on iteration 67 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 66 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.472943 -0.168139  0.023459
# Human       0.579389 -0.167718  0.293526
# Macaque     0.234501  0.167277  0.290610
# ____________________
# working on iteration 68 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 67 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.523657 -0.343686  0.164628
# Human      -0.329422 -0.499585  0.034406
# Macaque    -0.158949 -0.338332  0.397851
# ____________________
# working on iteration 69 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 68 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.265000  0.124984 -0.018634
# Human       0.090457 -0.299607  0.050873
# Macaque     0.110998  0.070046  0.144622
# ____________________
# working on iteration 70 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 69 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.581387 -0.474039  0.308305
# Human       0.575643 -0.522180  0.433399
# Macaque     0.075187  0.051173  0.252445
# ____________________
# working on iteration 71 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 70 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.048733  0.144326  0.400056
# Human       0.031045 -0.046233  0.303958
# Macaque     0.100804  0.555029  0.391864
# ____________________
# working on iteration 72 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 71 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.563193 -0.667010  0.285121
# Human      -0.079666 -0.632923 -0.003820
# Macaque    -0.582319  0.308484  0.053374
# ____________________
# working on iteration 73 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 72 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.056201 -0.023247  0.033856
# Human       0.247829 -0.307744  0.085882
# Macaque    -0.057869  0.404421  0.163862
# ____________________
# working on iteration 74 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 73 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.528835 -0.618299 -0.030034
# Human      -0.105258 -0.516910 -0.206500
# Macaque    -0.444399 -0.158854  0.070327
# ____________________
# working on iteration 75 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# ...
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 75 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.238068 -0.092473  0.438655
# Human      -0.141317  0.096970  0.083727
# Macaque    -0.242052  0.092928  0.255439
# ____________________
# working on iteration 77 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 76 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.405527 -0.698476 -0.338996
# Human      -0.425248 -0.436618 -0.475109
# Macaque    -0.305544  0.174058 -0.203253
# ____________________
# working on iteration 78 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 77 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.398864 -0.322984 -0.607929
# Human      -0.395307 -0.436627 -0.578370
# Macaque    -0.332967 -0.134076 -0.158947
# ____________________
# working on iteration 79 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 78 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.067548 -0.193823 -0.709577
# Human       0.218893 -0.346335 -0.466781
# Macaque     0.243630  0.242260 -0.196280
# ____________________
# working on iteration 80 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 79 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.516036  0.500157  0.007809
# Human       0.577974  0.172462 -0.028754
# Macaque     0.126731  0.690320  0.048920
# ____________________
# working on iteration 81 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 80 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.403677 -0.447735  0.187428
# Human      -0.185942 -0.410102  0.149989
# Macaque    -0.368435 -0.325998  0.144463
# ____________________
# working on iteration 82 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 81 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.777332 -0.504447  0.239210
# Human       0.751333 -0.540259  0.061273
# Macaque     0.421643 -0.113324  0.444282
# ____________________
# working on iteration 83 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 82 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.167542 -0.622625 -0.043760
# Human       0.327274 -0.604542 -0.042589
# Macaque     0.346131 -0.318037 -0.010540
# ____________________
# working on iteration 84 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 83 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.237551 -0.274349 -0.394278
# Human       0.218911 -0.485596 -0.486023
# Macaque    -0.006922  0.013522 -0.310817
# ____________________
# working on iteration 85 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 84 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.630234 -0.420819 -0.132966
# Human      -0.372724 -0.597120 -0.139941
# Macaque    -0.542597  0.090584 -0.007612
# ____________________
# working on iteration 86 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 85 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.208526 -0.613291  0.190193
# Human       0.597052 -0.747681 -0.170325
# Macaque    -0.212401  0.058278  0.229789
# ____________________
# working on iteration 87 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 86 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.132381  0.456814 -0.189643
# Human      -0.091432 -0.191726 -0.455731
# Macaque    -0.264663  0.681792 -0.451131
# ____________________
# working on iteration 88 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 87 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.232864  0.220852 -0.382406
# Human      -0.135784 -0.309087 -0.412007
# Macaque    -0.210187  0.168703 -0.105640
# ____________________
# working on iteration 89 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 88 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.190786 -0.115035  0.541464
# Human       0.387281 -0.309052  0.323582
# Macaque     0.116477 -0.147513  0.261006
# ____________________
# working on iteration 90 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 89 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.479282 -0.108780 -0.089734
# Human       0.180396 -0.462263 -0.317578
# Macaque    -0.085956  0.230614  0.067202
# ____________________
# working on iteration 91 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 90 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.060417 -0.001146 -0.327707
# Human       0.032642 -0.046653 -0.551382
# Macaque    -0.026593  0.136658 -0.085455
# ____________________
# working on iteration 92 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 91 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.143641 -0.354351 -0.461850
# Human       0.206546 -0.140959 -0.606092
# Macaque    -0.585580  0.087954 -0.393049
# ____________________
# working on iteration 93 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 92 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.680847  0.079528  0.291487
# Human       0.625178 -0.006379  0.325364
# Macaque    -0.211217  0.153063  0.349027
# ____________________
# working on iteration 94 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 93 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.692899 -0.344415  0.112124
# Human       0.599932 -0.490038  0.036299
# Macaque     0.554264 -0.034323  0.086568
# ____________________
# working on iteration 95 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 94 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.222437 -0.057083  0.267870
# Human       0.517929 -0.149493  0.111627
# Macaque    -0.462495 -0.191570 -0.030704
# ____________________
# working on iteration 96 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 95 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.490202 -0.453107 -0.095582
# Human       0.403411 -0.361114 -0.027554
# Macaque    -0.188021 -0.165533 -0.300070
# ____________________
# working on iteration 97 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 96 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.614682 -0.311828 -0.137108
# Human       0.630420 -0.365614 -0.374137
# Macaque     0.154052 -0.237751 -0.142968
# ____________________
# working on iteration 98 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 97 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee -0.076410 -0.573954 -0.232695
# Human      -0.036247 -0.729304 -0.468375
# Macaque     0.017354 -0.447928 -0.309399
# ____________________
# working on iteration 99 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 98 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.352650 -0.116543  0.255235
# Human       0.414621 -0.301061  0.160694
# Macaque     0.324564 -0.173444  0.129667
# ____________________
# working on iteration 100 of 100
# calculating random expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity
# ===== 99 results =====
#                 C1_r      C2_r      C3_r
# Species
# Chimpanzee  0.671674  0.264472  0.569765
# Human       0.617688  0.008048  0.629845
# Macaque     0.444700  0.129153  0.436418
# ____________________

# %%
# concatenate results
randos = pandas.concat(results)

# %%
# save it, so you don't have to run that whole thing again
#randos.to_csv('/Users/jacobv/Science/PLS_GXP/XSpecies/random_mats.csv')

# %%
# load it if necessary
# randos = pandas.read_csv('/Users/jacobv/Science/PLS_GXP/XSpecies/random_mats.csv',
#                         index_col=0)

# %%
# build it into a summarized dataframe
randos.loc[:,'ind'] = range(len(randos)) 
rtall = randos.melt('ind',['C1_r','C2_r','C3_r'],'component','expr')
rtall.loc[:,'Species'] = ['%s_Null'%x for x in randos.Species] * 3
rtall.loc[:,'Species2'] = [x for x in randos.Species] * 3
rtall.loc[:,'ID'] = [x for x in randos.ID] * 3

# %%
# concatenate it with the "true" results for comparison
vtall = pandas.concat([tall,rtall])

# %%
# set some colors
pal = [sns.color_palette('cividis')[-2],
       sns.color_palette('viridis')[-2],
       sns.color_palette('magma')[-2]]

# %%
figdir = '/Users/jacobv/Dropbox/Work/Projects/PLS_ABA/Manuscript/Figs/SubFigs/'

# %%
# plot the null distributions as violin plots over the boxplots from 
# earlier. NOTE: this aggregates null distributions across donors
# which doesn't make that much sense, as each donor has different data
# and therefore has their own unique null.
sns.swarmplot(x='component',y='expr',hue='Species',data=tall,dodge=True,palette=pal)
sns.boxplot(x='component',y='expr',hue='Species',data=tall,color='gray')
plt.ylabel('Correlation w/ ABA Component')
g = sns.violinplot(x='component',y='expr',hue='Species2',data=rtall,color='gray')
plt.ylabel('Correlation w/ ABA Component')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
g.set_xticklabels(['C1','C2','C3'])
# plt.savefig(os.path.join(figdir,'XSpecies_null_simple.pdf'),
#            bbox_inches='tight')
# Out:
# [Text(0, 0, 'C1'), Text(1, 0, 'C2'), Text(2, 0, 'C3')]

# %% [markdown]
# To overcome the *note* above, I wanted to plot the individual level null distributions against the "true" values.

# %%
#jnk = ['o']*((len(subsum)*3)-1) + ['x']

# %%
tall.loc[:,'ID'] = subsum.ID.tolist() * 3

# %%
plt.subplots(figsize=(12,8))
sns.stripplot(x='ID',y='expr',hue='component',data=tall,
              palette=pal,dodge=True,s=15)
g = sns.violinplot(x='ID',y='expr',data=rtall,color='gray',cut=0,
                   hue='component')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
g.set_xticklabels(subsum.Species.tolist(),rotation=90)
plt.xlabel('Donor')
plt.ylabel('Regional Correlation to \nABA Expression (r)')
# plt.savefig(os.path.join(figdir,'SubFigs/XSpecies_null_indiv.pdf'),
#            bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Regional Correlation to \nABA Expression (r)')

# %%
# generate exact p-values for each subject
for i,row in subsum.iterrows():
    for c in range(1,4):
        null = randos[randos.ID==row['ID']]['C%s_r'%c].sort_values().values
        val = row['C%s_r'%c]
        p = len(null[null>val]) / len(null)
        subsum.loc[i,'C%s_p(r)'%c] = p

# %%
subsum.head()
# Out:
#         ID Species      C1_r    C1_rho  n_valid      C2_r    C2_rho      C3_r  \
# 0  HSB123R   Human  0.907358  0.833333      9.0  0.900041  0.766667  0.700795
# 1  HSB126R   Human  0.937267  0.900000      9.0  0.956661  0.900000  0.741523
# 2  HSB130L   Human  0.927115  0.983333      9.0  0.903253  0.850000  0.811477
# 3  HSB135R   Human  0.971048  0.933333      9.0  0.937222  0.800000  0.768346
# 4  HSB136R   Human  0.980438  0.904762      8.0  0.955484  0.690476  0.807903
#
#      C3_rho  ind  C1_p(r)  C2_p(r)  C3_p(r)
# 0  0.816667    0      0.0      0.0     0.02
# 1  0.833333    1      0.0      0.0     0.00
# 2  0.816667    2      0.0      0.0     0.00
# 3  0.800000    3      0.0      0.0     0.00
# 4  0.880952    4      0.0      0.0     0.01

# %% [markdown]
# # PC comparison

# %% [markdown]
# Okay, so these are almost all significant for all components. Not terribly surprising. But, there is maybe another null model necessary. One might just point out that perhaps the overall brain gene expression patterns across species is highly similar, and that any biological signal will be highly reproducible across datasets. So, here we want to set up a distribution of r-values (representing reproducibility) for other biologically meaningful signals, to see how common it is to demonstrate a reproducible regional expression pattern across these datasets.
#
# The easiest way to drum up a bunch of biological signals is probably to use the AHBA prinicipal components. So, we'll create a distribution of r-values across AHBA PCs, and compare our PLS Component r-values to this distribution

# %%
pcdiv = pandas.read_csv('/Users/jacobv/Science/PLS_GXP/Allen_Macrostructure_PCs.csv',
                     index_col = 0)

# %%
pcs = pandas.read_csv('/Users/jacobv/Science/PLS_GXP/Allen_PC_matrix.csv',
                     index_col = 0)

# %%
# this is pretty much the same code as above, but adapted to use the
# Allen PCs rather than scrambled data
print('calculating PC expression')
jdf = pandas.DataFrame(columns = pcs.columns)
catch = []
count = 0
for i,ID in enumerate(df.ID.unique()):
    print('working on %s of 16'%(i+1))
    for region in df.ROI.unique():
        jnk = pandas.DataFrame(df[(df.ROI==region) & (df.ID==ID)],copy=True)
        if jnk.shape[0] == 0: continue
        jdf.loc[count,'ID'] = jnk.iloc[0]['ID']
        jdf.loc[count,'ROI'] = jnk.iloc[0]['ROI']
        jdf.loc[count,'Species'] = jnk.iloc[0]['Species']
        jnk.index = jnk.gene_symbol.values
        jnk = jnk.loc[shared]
        jdf.loc[count,pcs.columns] = np.dot(jnk['value'].values,pcs.loc[jnk.index].values)
        count+=1
        #catch.append(jnk)

# calculate similarity
print('calculating similarity')
for name, div in mapper.items():
    jdf.loc[jdf[jdf.ROI.isin(div)].index,'MacroStructure'] = name

# stupid value conversion
jnk = pandas.DataFrame(pandas.to_numeric(jdf[pcs.columns].values.flat,
                                          ).reshape(len(jdf),len(pcs.columns)),
                      index = jdf,columns=pcs.columns)
for col in [x for x in jdf.columns if x not in jnk.columns]:
    jnk.loc[:,col] = jdf[col].values
jdf = jnk

jpdfs = {}
for pc in pcs.columns:
    jpdf = jdf[['ID',pc,'MacroStructure']
                  ].set_index(['ID'],append=True
                             ).pivot_table(index='ID',
                                           columns='MacroStructure',
                                           values=pc)
    #gpdf.drop('GangEm',axis=1,inplace=True)
    for ind,row in jpdf.iterrows():
        n_valid = len([x for x in row.values if pandas.notnull(x)])
        jpdf.loc[ind,'n_valid'] = n_valid
    jpdfs.update({pc: jpdf})

for c in pcs.columns:
    cjdf = jpdfs[c]
    aba = pandas.DataFrame(pcdiv['P%s'%c])
    aba = aba.loc[cjdf.columns[:-1]]
    for i,row in cjdf.iterrows():
        forcorr = pandas.DataFrame(aba,copy=True)
        if row['n_valid'] > 4:
            forcorr.loc[:,'gvec'] = row.values[:-1]
            forcorr.dropna(inplace=True)
            r = stats.pearsonr(forcorr['P%s'%c].values,
                              forcorr['gvec'].values)[0]
            rho = stats.spearmanr(forcorr['P%s'%c].values,
                              forcorr['gvec'].values)[0]
            cjdf.loc[i,'%s_r'%c] = r
            cjdf.loc[i,'%s_rho'%c] = rho

cols = ['ID', 'Species',]
jsum = pandas.DataFrame(jpdfs[list(jpdfs.keys())[0]].index)
for col in cols:
    jsum.loc[:,col] = jdf.groupby('ID')[col].first().values
for c in pcs.columns:
    jsum.loc[:,'%s_r'%c] = jpdfs[c].loc[:,'%s_r'%c].values
    jsum.loc[:,'%s_rho'%c] = jpdfs[c].loc[:,'%s_rho'%c].values
    jsum.loc[:,'n_valid'] = jpdfs[c].loc[:,'n_valid'].values
# Out:
# calculating PC expression
# working on 1 of 16
# working on 2 of 16
# working on 3 of 16
# working on 4 of 16
# working on 5 of 16
# working on 6 of 16
# working on 7 of 16
# working on 8 of 16
# working on 9 of 16
# working on 10 of 16
# working on 11 of 16
# working on 12 of 16
# working on 13 of 16
# working on 14 of 16
# working on 15 of 16
# working on 16 of 16
# calculating similarity

# %%
subsum.groupby('Species').mean()
# Out:
#                 C1_r    C1_rho   n_valid      C2_r    C2_rho      C3_r  \
# Species
# Chimpanzee  0.886414  0.890000  8.800000  0.915117  0.807619  0.734975
# Human       0.940132  0.900794  8.833333  0.934737  0.792857  0.759394
# Macaque     0.787925  0.840952  8.600000  0.951396  0.822857  0.624051
#
#               C3_rho   ind  C1_p(r)  C2_p(r)  C3_p(r)
# Species
# Chimpanzee  0.810476   8.0    0.006      0.0    0.010
# Human       0.816270   2.5    0.000      0.0    0.005
# Macaque     0.682381  13.0    0.006      0.0    0.034

# %%
# now let't melt that df
jsum.loc[:,'ind'] = range(len(jsum))
jtall = jsum.melt('ind',[x for x in jsum.columns if '_r' in x and 'ho' not in x],
                  'component','expr')
jtall.loc[:,'Species'] = jsum.Species.tolist() * len(pcs.columns)
jtall.loc[:,'ID'] = jsum.ID.tolist() * len(pcs.columns)

jtall.loc[:,'c'] = [int(x.split('C')[1].split('_')[0]) for x in jtall.component.values]

# %%
# generating p-values
comps = pandas.DataFrame(index=jsum.ID.values)
for i,row in jsum.iterrows():
    ID = row['ID']
    dist = row[[x for x in jsum.columns if '_r' in x and 'ho' not in x]].values
    for c in range(1,4):
        val = subsum[subsum.ID==ID]['C%s_r'%c].values[0]
        p = len(dist[dist>val]) / 100
        
        comps.loc[ID,'C%s'%c] = p
    sig = sorted(dist)[95]
    comps.loc[ID,'sig'] = sig

# %%
# having a look
comps
# Out:
#            C1    C2    C3       sig
# HSB123R  0.03  0.03  0.08  0.875212
# HSB126R  0.02  0.02  0.14  0.910868
# HSB130L  0.03  0.04  0.07  0.881613
# HSB135R  0.00  0.02  0.07  0.836485
# HSB136R  0.01  0.02  0.05  0.815354
# HSB145R  0.03  0.03  0.13  0.859251
# PTB162L  0.03  0.01  0.17  0.851448
# PTB164R  0.03  0.03  0.09  0.831503
# PTB165R  0.05  0.04  0.10  0.879810
# PTB166R  0.06  0.03  0.12  0.930139
# PTB167R  0.04  0.01  0.12  0.861033
# RMB160L  0.07  0.01  0.14  0.897283
# RMB161L  0.06  0.01  0.20  0.931355
# RMB196R  0.02  0.01  0.11  0.860893
# RMB218L  0.04  0.01  0.23  0.861956
# RMB219L  0.46  0.00  0.40  0.842646

# %%
# And now we plot the "null" distribution, along with the "true"
# r-values of the PLS Components
sns.stripplot(x='ID',y='expr',hue='component',data=tall,palette=pal)
g = sns.violinplot(x='ID',y='expr',data=jtall,color='gray',cut=0)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
count = 0
for i,row in comps.iterrows():
    plt.plot([(count-0.3),(count+0.3)],[row['sig'],row['sig']],ls='--',c='k')
    count+=1
g.set_xticklabels(subsum.Species.tolist(),rotation=90)
plt.xlabel('Donor')
plt.ylabel('Regional Correlation to \nABA Expression (r)')
# plt.savefig(os.path.join(figdir,'XSpecies_signull_indiv.pdf'),
#            bbox_inches='tight')
